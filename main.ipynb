# %%
import numpy as np
import pandas as pd
import cv2
from matplotlib import pyplot as plt
import torch

# %%
img = cv2.imread("knife.jpg")
img = cv2.cvtColor(img , cv2.COLOR_BGR2RGB)

# %%
plt.imshow(img)
